# %% [markdown]
# # Week 12: Model Evaluation & Ensemble Methods
#
# Techniques to rigorously assess model performance and improve predictive power through ensembles.

# %% [markdown]
# ## 1. Model Evaluation Metrics
#
# Choosing the right metrics beyond simple accuracy.

# %%
from sklearn.metrics import classification_report
y_true = [0, 1, 2, 2, 0]
y_pred = [0, 0, 2, 2, 0]
print(classification_report(y_true, y_pred))

# %% [markdown]
# ## 2. Ensemble Methods
#
# Improving performance by combining multiple models.

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

clf1 = LogisticRegression()
clf2 = SVC()
eclf = VotingClassifier(estimators=[('lr', clf1), ('svc', clf2)], voting='hard')
# eclf.fit(X, y)
