# %% [markdown]
# # Week 2: Object-Oriented Python for Data Science
#
# This week, we will master creating robust, reusable code components using object-oriented principles, which are essential for building scalable data pipelines.

# %% [markdown]
# ## 1. Classes and Special Methods
#
# Special methods (dunder methods) allow us to make our objects behave like built-in types.

# %%
class DataPoint:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __repr__(self):
        return f"DataPoint(x={self.x}, y={self.y})"

pt = DataPoint(1, 2)
print(pt)

# %% [markdown]
# ## 2. Dataclasses
#
# Introduced in Python 3.7, `dataclasses` reduce boilerplate code for classes that primarily store data.

# %%
from dataclasses import dataclass

@dataclass
class User:
    name: str
    age: int

u = User("Alice", 30)
print(u)
