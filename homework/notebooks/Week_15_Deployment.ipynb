# %% [markdown]
# # Week 15: Deployment & Serving Models
#
# Moving from notebooks to production: serving models as APIs with `FastAPI`.

# %% [markdown]
# ## 1. Serving Models with FastAPI
#
# Creating a simple REST API to serve predictions.

# %%
from fastapi import FastAPI

app = FastAPI()

@app.post("/predict")
def predict(data: dict):
    # return model.predict(data)
    return {"prediction": "result"}
