# %% [markdown]
# # Week 16: Project Capstone & Best Practices
#
# Integrating everything: testing, documentation, and a final capstone project.

# %% [markdown]
# ## 1. Professional Best Practices
#
# Writing tests with `pytest` and documenting with docstrings.

# %%
# Example test
def add(a, b):
    return a + b

def test_add():
    assert add(1, 2) == 3
