# %% [markdown]
# # Week 14: Data Engineering Fundamentals
#
# Learning to interact with external data sources like APIs and SQL databases, which is essential for end-to-end data pipelines.

# %% [markdown]
# ## 1. Interacting with APIs
#
# Using the `requests` library to fetch data from web APIs.

# %%
import requests

# Example request (URL placeholder)
# response = requests.get('https://api.example.com/data')
# data = response.json()

# %% [markdown]
# ## 2. Databases with SQL
#
# Querying databases using `pandas` and `sqlalchemy`.

# %%
import pandas as pd
from sqlalchemy import create_engine

# engine = create_engine('sqlite:///:memory:')
# df = pd.read_sql('SELECT * FROM table', engine)
